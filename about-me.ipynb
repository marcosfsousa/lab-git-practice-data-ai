# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Marcos Sousa"
reason = "I have a particular interest in AI, specifically LLMs, given the tremendous shift in the IT area and the Internet altogether"
fun_fact = "improve my understanding of AI and how to empower myself and others to become better developers"

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A goal for me during the course is: {fun_fact}.")
# Out:
# Hi! My name is Marcos Sousa. I’m excited to learn because I have a particular interest in AI, specifically LLMs, given the tremendous shift in the IT area and the Internet altogether. A goal for me during the course is: improve my understanding of AI and how to empower myself and others to become better developers.
